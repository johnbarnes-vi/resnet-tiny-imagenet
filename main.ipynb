# %%
# Importing necessary libraries to unzip `tiny-imagenet-200.zip`
import os
import zipfile
import random
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# Importing pytorch libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# Importing custom modules
from models.cnn import SimpleCNN
from models.resnet18 import ResNet18
from models.cnn256 import SimpleCNN256
from models.resnet34 import resnet34

# %%
# Unzip the dataset
#with zipfile.ZipFile("tiny-imagenet-200.zip", 'r') as zip_ref:
#    zip_ref.extractall()

#!python .\tiny-imagenet-200\data-prep.py

# %%
# Lets see the directory structure of tiny-imagenet-200
def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        jpeg_files = [f for f in files if f.endswith('.JPEG')]
        if jpeg_files:  # if the list is not empty
            print('{}Number of JPEG files: {}'.format(subindent, len(jpeg_files)))
        for f in files:
            if f.endswith('.txt'):
                print('{}{}'.format(subindent, f))

list_files('tiny-imagenet-200')
# Out:
# tiny-imagenet-200/
#     wnids.txt
#     words.txt
#     test/
#         images/
#             Number of JPEG files: 10000
#     train/
#         n01443537/
#             n01443537_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01629819/
#             n01629819_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01641577/
#             n01641577_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01644900/
#             n01644900_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01698640/
#             n01698640_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01742172/
#             n01742172_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01768244/
#             n01768244_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01770393/
#             n01770393_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01774384/
#             n01774384_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01774750/
#             n01774750_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01784675/
#             n01784675_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01855672/
#             n01855672_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01882714/
#             n01882714_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01910747/
#             n01910747_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01917289/
#             n01917289_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01944390/
#             n01944390_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01945685/
#             n01945685_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01950731/
#             n01950731_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01983481/
#             n01983481_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n01984695/
#             n01984695_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02002724/
#             n02002724_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02056570/
#             n02056570_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02058221/
#             n02058221_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02074367/
#             n02074367_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02085620/
#             n02085620_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02094433/
#             n02094433_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02099601/
#             n02099601_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02099712/
#             n02099712_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02106662/
#             n02106662_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02113799/
#             n02113799_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02123045/
#             n02123045_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02123394/
#             n02123394_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02124075/
#             n02124075_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02125311/
#             n02125311_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02129165/
#             n02129165_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02132136/
#             n02132136_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02165456/
#             n02165456_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02190166/
#             n02190166_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02206856/
#             n02206856_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02226429/
#             n02226429_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02231487/
#             n02231487_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02233338/
#             n02233338_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02236044/
#             n02236044_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02268443/
#             n02268443_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02279972/
#             n02279972_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02281406/
#             n02281406_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02321529/
#             n02321529_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02364673/
#             n02364673_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02395406/
#             n02395406_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02403003/
#             n02403003_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02410509/
#             n02410509_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02415577/
#             n02415577_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02423022/
#             n02423022_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02437312/
#             n02437312_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02480495/
#             n02480495_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02481823/
#             n02481823_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02486410/
#             n02486410_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02504458/
#             n02504458_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02509815/
#             n02509815_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02666196/
#             n02666196_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02669723/
#             n02669723_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02699494/
#             n02699494_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02730930/
#             n02730930_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02769748/
#             n02769748_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02788148/
#             n02788148_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02791270/
#             n02791270_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02793495/
#             n02793495_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02795169/
#             n02795169_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02802426/
#             n02802426_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02808440/
#             n02808440_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02814533/
#             n02814533_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02814860/
#             n02814860_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02815834/
#             n02815834_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02823428/
#             n02823428_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02837789/
#             n02837789_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02841315/
#             n02841315_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02843684/
#             n02843684_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02883205/
#             n02883205_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02892201/
#             n02892201_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02906734/
#             n02906734_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02909870/
#             n02909870_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02917067/
#             n02917067_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02927161/
#             n02927161_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02948072/
#             n02948072_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02950826/
#             n02950826_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02963159/
#             n02963159_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02977058/
#             n02977058_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02988304/
#             n02988304_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n02999410/
#             n02999410_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03014705/
#             n03014705_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03026506/
#             n03026506_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03042490/
#             n03042490_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03085013/
#             n03085013_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03089624/
#             n03089624_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03100240/
#             n03100240_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03126707/
#             n03126707_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03160309/
#             n03160309_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03179701/
#             n03179701_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03201208/
#             n03201208_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03250847/
#             n03250847_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03255030/
#             n03255030_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03355925/
#             n03355925_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03388043/
#             n03388043_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03393912/
#             n03393912_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03400231/
#             n03400231_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03404251/
#             n03404251_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03424325/
#             n03424325_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03444034/
#             n03444034_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03447447/
#             n03447447_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03544143/
#             n03544143_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03584254/
#             n03584254_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03599486/
#             n03599486_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03617480/
#             n03617480_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03637318/
#             n03637318_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03649909/
#             n03649909_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03662601/
#             n03662601_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03670208/
#             n03670208_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03706229/
#             n03706229_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03733131/
#             n03733131_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03763968/
#             n03763968_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03770439/
#             n03770439_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03796401/
#             n03796401_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03804744/
#             n03804744_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03814639/
#             n03814639_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03837869/
#             n03837869_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03838899/
#             n03838899_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03854065/
#             n03854065_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03891332/
#             n03891332_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03902125/
#             n03902125_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03930313/
#             n03930313_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03937543/
#             n03937543_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03970156/
#             n03970156_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03976657/
#             n03976657_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03977966/
#             n03977966_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03980874/
#             n03980874_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03983396/
#             n03983396_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n03992509/
#             n03992509_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04008634/
#             n04008634_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04023962/
#             n04023962_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04067472/
#             n04067472_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04070727/
#             n04070727_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04074963/
#             n04074963_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04099969/
#             n04099969_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04118538/
#             n04118538_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04133789/
#             n04133789_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04146614/
#             n04146614_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04149813/
#             n04149813_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04179913/
#             n04179913_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04251144/
#             n04251144_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04254777/
#             n04254777_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04259630/
#             n04259630_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04265275/
#             n04265275_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04275548/
#             n04275548_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04285008/
#             n04285008_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04311004/
#             n04311004_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04328186/
#             n04328186_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04356056/
#             n04356056_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04366367/
#             n04366367_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04371430/
#             n04371430_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04376876/
#             n04376876_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04398044/
#             n04398044_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04399382/
#             n04399382_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04417672/
#             n04417672_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04456115/
#             n04456115_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04465501/
#             n04465501_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04486054/
#             n04486054_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04487081/
#             n04487081_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04501370/
#             n04501370_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04507155/
#             n04507155_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04532106/
#             n04532106_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04532670/
#             n04532670_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04540053/
#             n04540053_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04560804/
#             n04560804_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04562935/
#             n04562935_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04596742/
#             n04596742_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n04597913/
#             n04597913_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n06596364/
#             n06596364_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07579787/
#             n07579787_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07583066/
#             n07583066_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07614500/
#             n07614500_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07615774/
#             n07615774_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07695742/
#             n07695742_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07711569/
#             n07711569_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07715103/
#             n07715103_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07720875/
#             n07720875_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07734744/
#             n07734744_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07747607/
#             n07747607_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07749582/
#             n07749582_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07753592/
#             n07753592_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07768694/
#             n07768694_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07871810/
#             n07871810_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07873807/
#             n07873807_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07875152/
#             n07875152_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n07920052/
#             n07920052_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n09193705/
#             n09193705_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n09246464/
#             n09246464_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n09256479/
#             n09256479_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n09332890/
#             n09332890_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n09428293/
#             n09428293_boxes.txt
#             images/
#                 Number of JPEG files: 500
#         n12267677/
#             n12267677_boxes.txt
#             images/
#                 Number of JPEG files: 500
#     val/
#         n01443537/
#             Number of JPEG files: 50
#         n01629819/
#             Number of JPEG files: 50
#         n01641577/
#             Number of JPEG files: 50
#         n01644900/
#             Number of JPEG files: 50
#         n01698640/
#             Number of JPEG files: 50
#         n01742172/
#             Number of JPEG files: 50
#         n01768244/
#             Number of JPEG files: 50
#         n01770393/
#             Number of JPEG files: 50
#         n01774384/
#             Number of JPEG files: 50
#         n01774750/
#             Number of JPEG files: 50
#         n01784675/
#             Number of JPEG files: 50
#         n01855672/
#             Number of JPEG files: 50
#         n01882714/
#             Number of JPEG files: 50
#         n01910747/
#             Number of JPEG files: 50
#         n01917289/
#             Number of JPEG files: 50
#         n01944390/
#             Number of JPEG files: 50
#         n01945685/
#             Number of JPEG files: 50
#         n01950731/
#             Number of JPEG files: 50
#         n01983481/
#             Number of JPEG files: 50
#         n01984695/
#             Number of JPEG files: 50
#         n02002724/
#             Number of JPEG files: 50
#         n02056570/
#             Number of JPEG files: 50
#         n02058221/
#             Number of JPEG files: 50
#         n02074367/
#             Number of JPEG files: 50
#         n02085620/
#             Number of JPEG files: 50
#         n02094433/
#             Number of JPEG files: 50
#         n02099601/
#             Number of JPEG files: 50
#         n02099712/
#             Number of JPEG files: 50
#         n02106662/
#             Number of JPEG files: 50
#         n02113799/
#             Number of JPEG files: 50
#         n02123045/
#             Number of JPEG files: 50
#         n02123394/
#             Number of JPEG files: 50
#         n02124075/
#             Number of JPEG files: 50
#         n02125311/
#             Number of JPEG files: 50
#         n02129165/
#             Number of JPEG files: 50
#         n02132136/
#             Number of JPEG files: 50
#         n02165456/
#             Number of JPEG files: 50
#         n02190166/
#             Number of JPEG files: 50
#         n02206856/
#             Number of JPEG files: 50
#         n02226429/
#             Number of JPEG files: 50
#         n02231487/
#             Number of JPEG files: 50
#         n02233338/
#             Number of JPEG files: 50
#         n02236044/
#             Number of JPEG files: 50
#         n02268443/
#             Number of JPEG files: 50
#         n02279972/
#             Number of JPEG files: 50
#         n02281406/
#             Number of JPEG files: 50
#         n02321529/
#             Number of JPEG files: 50
#         n02364673/
#             Number of JPEG files: 50
#         n02395406/
#             Number of JPEG files: 50
#         n02403003/
#             Number of JPEG files: 50
#         n02410509/
#             Number of JPEG files: 50
#         n02415577/
#             Number of JPEG files: 50
#         n02423022/
#             Number of JPEG files: 50
#         n02437312/
#             Number of JPEG files: 50
#         n02480495/
#             Number of JPEG files: 50
#         n02481823/
#             Number of JPEG files: 50
#         n02486410/
#             Number of JPEG files: 50
#         n02504458/
#             Number of JPEG files: 50
#         n02509815/
#             Number of JPEG files: 50
#         n02666196/
#             Number of JPEG files: 50
#         n02669723/
#             Number of JPEG files: 50
#         n02699494/
#             Number of JPEG files: 50
#         n02730930/
#             Number of JPEG files: 50
#         n02769748/
#             Number of JPEG files: 50
#         n02788148/
#             Number of JPEG files: 50
#         n02791270/
#             Number of JPEG files: 50
#         n02793495/
#             Number of JPEG files: 50
#         n02795169/
#             Number of JPEG files: 50
#         n02802426/
#             Number of JPEG files: 50
#         n02808440/
#             Number of JPEG files: 50
#         n02814533/
#             Number of JPEG files: 50
#         n02814860/
#             Number of JPEG files: 50
#         n02815834/
#             Number of JPEG files: 50
#         n02823428/
#             Number of JPEG files: 50
#         n02837789/
#             Number of JPEG files: 50
#         n02841315/
#             Number of JPEG files: 50
#         n02843684/
#             Number of JPEG files: 50
#         n02883205/
#             Number of JPEG files: 50
#         n02892201/
#             Number of JPEG files: 50
#         n02906734/
#             Number of JPEG files: 50
#         n02909870/
#             Number of JPEG files: 50
#         n02917067/
#             Number of JPEG files: 50
#         n02927161/
#             Number of JPEG files: 50
#         n02948072/
#             Number of JPEG files: 50
#         n02950826/
#             Number of JPEG files: 50
#         n02963159/
#             Number of JPEG files: 50
#         n02977058/
#             Number of JPEG files: 50
#         n02988304/
#             Number of JPEG files: 50
#         n02999410/
#             Number of JPEG files: 50
#         n03014705/
#             Number of JPEG files: 50
#         n03026506/
#             Number of JPEG files: 50
#         n03042490/
#             Number of JPEG files: 50
#         n03085013/
#             Number of JPEG files: 50
#         n03089624/
#             Number of JPEG files: 50
#         n03100240/
#             Number of JPEG files: 50
#         n03126707/
#             Number of JPEG files: 50
#         n03160309/
#             Number of JPEG files: 50
#         n03179701/
#             Number of JPEG files: 50
#         n03201208/
#             Number of JPEG files: 50
#         n03250847/
#             Number of JPEG files: 50
#         n03255030/
#             Number of JPEG files: 50
#         n03355925/
#             Number of JPEG files: 50
#         n03388043/
#             Number of JPEG files: 50
#         n03393912/
#             Number of JPEG files: 50
#         n03400231/
#             Number of JPEG files: 50
#         n03404251/
#             Number of JPEG files: 50
#         n03424325/
#             Number of JPEG files: 50
#         n03444034/
#             Number of JPEG files: 50
#         n03447447/
#             Number of JPEG files: 50
#         n03544143/
#             Number of JPEG files: 50
#         n03584254/
#             Number of JPEG files: 50
#         n03599486/
#             Number of JPEG files: 50
#         n03617480/
#             Number of JPEG files: 50
#         n03637318/
#             Number of JPEG files: 50
#         n03649909/
#             Number of JPEG files: 50
#         n03662601/
#             Number of JPEG files: 50
#         n03670208/
#             Number of JPEG files: 50
#         n03706229/
#             Number of JPEG files: 50
#         n03733131/
#             Number of JPEG files: 50
#         n03763968/
#             Number of JPEG files: 50
#         n03770439/
#             Number of JPEG files: 50
#         n03796401/
#             Number of JPEG files: 50
#         n03804744/
#             Number of JPEG files: 50
#         n03814639/
#             Number of JPEG files: 50
#         n03837869/
#             Number of JPEG files: 50
#         n03838899/
#             Number of JPEG files: 50
#         n03854065/
#             Number of JPEG files: 50
#         n03891332/
#             Number of JPEG files: 50
#         n03902125/
#             Number of JPEG files: 50
#         n03930313/
#             Number of JPEG files: 50
#         n03937543/
#             Number of JPEG files: 50
#         n03970156/
#             Number of JPEG files: 50
#         n03976657/
#             Number of JPEG files: 50
#         n03977966/
#             Number of JPEG files: 50
#         n03980874/
#             Number of JPEG files: 50
#         n03983396/
#             Number of JPEG files: 50
#         n03992509/
#             Number of JPEG files: 50
#         n04008634/
#             Number of JPEG files: 50
#         n04023962/
#             Number of JPEG files: 50
#         n04067472/
#             Number of JPEG files: 50
#         n04070727/
#             Number of JPEG files: 50
#         n04074963/
#             Number of JPEG files: 50
#         n04099969/
#             Number of JPEG files: 50
#         n04118538/
#             Number of JPEG files: 50
#         n04133789/
#             Number of JPEG files: 50
#         n04146614/
#             Number of JPEG files: 50
#         n04149813/
#             Number of JPEG files: 50
#         n04179913/
#             Number of JPEG files: 50
#         n04251144/
#             Number of JPEG files: 50
#         n04254777/
#             Number of JPEG files: 50
#         n04259630/
#             Number of JPEG files: 50
#         n04265275/
#             Number of JPEG files: 50
#         n04275548/
#             Number of JPEG files: 50
#         n04285008/
#             Number of JPEG files: 50
#         n04311004/
#             Number of JPEG files: 50
#         n04328186/
#             Number of JPEG files: 50
#         n04356056/
#             Number of JPEG files: 50
#         n04366367/
#             Number of JPEG files: 50
#         n04371430/
#             Number of JPEG files: 50
#         n04376876/
#             Number of JPEG files: 50
#         n04398044/
#             Number of JPEG files: 50
#         n04399382/
#             Number of JPEG files: 50
#         n04417672/
#             Number of JPEG files: 50
#         n04456115/
#             Number of JPEG files: 50
#         n04465501/
#             Number of JPEG files: 50
#         n04486054/
#             Number of JPEG files: 50
#         n04487081/
#             Number of JPEG files: 50
#         n04501370/
#             Number of JPEG files: 50
#         n04507155/
#             Number of JPEG files: 50
#         n04532106/
#             Number of JPEG files: 50
#         n04532670/
#             Number of JPEG files: 50
#         n04540053/
#             Number of JPEG files: 50
#         n04560804/
#             Number of JPEG files: 50
#         n04562935/
#             Number of JPEG files: 50
#         n04596742/
#             Number of JPEG files: 50
#         n04597913/
#             Number of JPEG files: 50
#         n06596364/
#             Number of JPEG files: 50
#         n07579787/
#             Number of JPEG files: 50
#         n07583066/
#             Number of JPEG files: 50
#         n07614500/
#             Number of JPEG files: 50
#         n07615774/
#             Number of JPEG files: 50
#         n07695742/
#             Number of JPEG files: 50
#         n07711569/
#             Number of JPEG files: 50
#         n07715103/
#             Number of JPEG files: 50
#         n07720875/
#             Number of JPEG files: 50
#         n07734744/
#             Number of JPEG files: 50
#         n07747607/
#             Number of JPEG files: 50
#         n07749582/
#             Number of JPEG files: 50
#         n07753592/
#             Number of JPEG files: 50
#         n07768694/
#             Number of JPEG files: 50
#         n07871810/
#             Number of JPEG files: 50
#         n07873807/
#             Number of JPEG files: 50
#         n07875152/
#             Number of JPEG files: 50
#         n07920052/
#             Number of JPEG files: 50
#         n09193705/
#             Number of JPEG files: 50
#         n09246464/
#             Number of JPEG files: 50
#         n09256479/
#             Number of JPEG files: 50
#         n09332890/
#             Number of JPEG files: 50
#         n09428293/
#             Number of JPEG files: 50
#         n12267677/
#             Number of JPEG files: 50

# %%
# Path and Files
path = './tiny-imagenet-200/train/'
wnid_labels = dict(line.strip().split('\t') for line in open('./tiny-imagenet-200/words.txt'))  # Corrected path
dirs = os.listdir(path)

# Read the wnids from wnids.txt into a set
with open('./tiny-imagenet-200/wnids.txt') as f:
    wnids = {line.strip() for line in f}

# Filter wnid_labels to only include the wnids in Tiny ImageNet
wnid_labels = {wnid: desc for wnid, desc in wnid_labels.items() if wnid in wnids}

len(wnid_labels) # We only want the mappings that are in tinynet
# Out:
# 200

# %%
# Define the function to randomly sample n images
def rsample_images(n):
    """
    Sample n random images from the train directory along with their English wnid representations and bounding boxes.

    Args:
    n (int): The number of images to sample.

    Returns:
    List[Tuple]: A list of tuples where each tuple contains wnid, image path, and bounding box.
    """
    samples_with_boxes = []
    for _ in range(n):
        random_dir = random.choice(dirs)
        random_image = random.choice(os.listdir(os.path.join(path, random_dir, 'images')))
        box_data = [line.strip().split('\t') for line in open(os.path.join(path, random_dir, f"{random_dir}_boxes.txt"))]
        box_for_image = [box for box in box_data if box[0] == random_image][0]
        samples_with_boxes.append((random_dir, os.path.join(path, random_dir, 'images', random_image), box_for_image))

    return samples_with_boxes

# %%
# Define the function to sample n images by wordnet-id
def sample_images_by_wnid(wnid, n):
    """
    Sample 'n' images of a specific wnid from the train directory along with their English wnid representations and bounding boxes.

    Args:
    wnid (str): The wnid of the images to sample.
    n (int): The number of images to sample.

    Returns:
    List[Tuple]: A list of tuples where each tuple contains wnid, image path, and bounding box.
    """
    samples_with_boxes = []
    image_dir = os.path.join(path, wnid, 'images')
    box_data = [line.strip().split('\t') for line in open(os.path.join(path, wnid, f"{wnid}_boxes.txt"))]
    
    for image_name in os.listdir(image_dir)[:n]:
        box_for_image = [box for box in box_data if box[0] == image_name][0]
        samples_with_boxes.append((wnid, os.path.join(image_dir, image_name), box_for_image))

    return samples_with_boxes

# %%
# Define the function to display images
def display_images(samples_with_boxes):
    """
    Display images along with their English wnid representations and bounding boxes.

    Args:
    samples_with_boxes (List[Tuple]): A list of tuples where each tuple contains wnid, image path, and bounding box.

    Returns:
    None
    """
    n = len(samples_with_boxes)
    fig, axs = plt.subplots(n, 1, figsize=(2, 2*n))
    if n == 1:
        axs = [axs]
    for i, (wnid, img_path, box) in enumerate(samples_with_boxes):
        img = Image.open(img_path)
        axs[i].imshow(img)
        axs[i].title.set_text(wnid_labels[wnid])
        axs[i].title.set_fontsize(8)

        x, y, w, h = map(int, box[1:])
        rect = patches.Rectangle((x, y), w, h, linewidth=1, edgecolor='r', facecolor='none')
        axs[i].add_patch(rect)

        axs[i].axis('off')

    plt.tight_layout()
    plt.show()

# %%
display_images(rsample_images(2))

# %%
#display_images(sample_images_by_wnid('n02099601',2))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define a transform for training data
train_transform = transforms.Compose([
    transforms.Pad(4),  # Pad the image by 4 pixels
    transforms.RandomCrop(64),  # Randomly crop a 64x64 region from the padded image
    transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally
    transforms.ToTensor(),  # Convert the image to a tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize to range [-1, 1]
])

# Define a transform for validation data
val_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert the image to a tensor
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize to range [-1, 1]
])


# Load Tiny ImageNet dataset
train_dataset = datasets.ImageFolder(root='./tiny-imagenet-200/train', transform=train_transform)
val_dataset = datasets.ImageFolder(root='./tiny-imagenet-200/val', transform=val_transform)



# Create data loaders
batch_size = 100
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)

# %%
len(train_loader)
# Out:
# 1000

# %%
# Inspect a batch from train_loader
train_images, train_labels = next(iter(train_loader))
print("Train images batch shape:", train_images.shape)
print("Train labels batch shape:", train_labels.shape)
print("Train images data type:", train_images.dtype)
print("Train labels data type:", train_labels.dtype)

# Inspect a batch from val_loader
val_images, val_labels = next(iter(val_loader))
print("Validation images batch shape:", val_images.shape)
print("Validation labels batch shape:", val_labels.shape)
print("Validation images data type:", val_images.dtype)
print("Validation labels data type:", val_labels.dtype)
# Out:
# Train images batch shape: torch.Size([100, 3, 64, 64])
# Train labels batch shape: torch.Size([100])
# Train images data type: torch.float32
# Train labels data type: torch.int64
# Validation images batch shape: torch.Size([100, 3, 64, 64])
# Validation labels batch shape: torch.Size([100])
# Validation images data type: torch.float32
# Validation labels data type: torch.int64

# %%
def train_model(model, train_loader, batch_size, criterion, optimizer, device, num_epochs):
    model.to(device)
    model.train()  # Set the model to training mode
    total_step = len(train_loader)
    
    for epoch in range(num_epochs):
        loss_list = []
        acc_list = []
        for i, (images, labels) in enumerate(train_loader):
            images = images.to(device)
            labels = labels.to(device)
            
            # Run the forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss_list.append(loss.item())

            # Backprop and perform optimisation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track the accuracy
            total = labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct = (predicted == labels).sum().item()
            acc_list.append(correct / total)

            # Uncomment for batch-wise training summaries
            #if (i + 1) % batch_size == 0:
            #    print(f'Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{total_step}], Loss: {loss.item():.4f}, Accuracy: {100*(correct / total):.2f}%')

        epoch_loss = np.mean(loss_list)
        epoch_acc = np.mean(acc_list)
        print(f'End of Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {100*epoch_acc:.2f}%')

    # Print the last epoch's average loss and accuracy
    print(f"\nFinal Training accuracy: {100*epoch_acc:.2f}%, Final Training loss: {epoch_loss:.4f}")

# %%
def evaluate_model(model, val_loader, criterion, device):
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    total_loss = 0
    with torch.no_grad():  # We don't need gradients for evaluation
        for i, (images, labels) in enumerate(val_loader):
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            loss = criterion(outputs, labels)
            total_loss += loss.item()
    
    print(f'Final Validation accuracy: {100 * correct / total:.2f}%, Final Validation loss: {total_loss / len(val_loader):.4f}')

# %% [markdown]
# ### Train CNN's

# %%
# Initialize SimpleCNN model and hyperparameters
cnn_model = SimpleCNN()
cnn_model.load_state_dict(torch.load("./model_params/cnn_model_parameters.pth")) # comment out to train fresh model
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn_model.parameters(), lr=0.001)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 25

# Train and then evaulate our model
train_model(cnn_model, train_loader, batch_size, criterion, optimizer, device, num_epochs) # optimizer changed to adam
evaluate_model(cnn_model, val_loader, criterion, device)

# Assume model is your trained model
torch.save(cnn_model.state_dict(), "./model_params/cnn_model_parameters.pth")
# Out:
# End of Epoch [1/25], Loss: 3.9376, Accuracy: 13.99%
# End of Epoch [2/25], Loss: 3.9280, Accuracy: 14.16%
# End of Epoch [3/25], Loss: 3.9256, Accuracy: 14.23%
# End of Epoch [4/25], Loss: 3.9332, Accuracy: 14.09%
# End of Epoch [5/25], Loss: 3.9222, Accuracy: 14.07%
# End of Epoch [6/25], Loss: 3.9301, Accuracy: 14.11%
# End of Epoch [7/25], Loss: 3.9207, Accuracy: 14.37%
# End of Epoch [8/25], Loss: 3.9215, Accuracy: 14.37%
# End of Epoch [9/25], Loss: 3.9283, Accuracy: 14.24%
# End of Epoch [10/25], Loss: 3.9213, Accuracy: 14.32%
# End of Epoch [11/25], Loss: 3.9172, Accuracy: 14.47%
# End of Epoch [12/25], Loss: 3.9127, Accuracy: 14.54%
# End of Epoch [13/25], Loss: 3.9222, Accuracy: 14.56%
# End of Epoch [14/25], Loss: 3.9175, Accuracy: 14.46%
# End of Epoch [15/25], Loss: 3.9137, Accuracy: 14.26%
# End of Epoch [16/25], Loss: 3.9206, Accuracy: 14.35%
# End of Epoch [17/25], Loss: 3.9166, Accuracy: 14.35%
# End of Epoch [18/25], Loss: 3.9167, Accuracy: 14.47%
# End of Epoch [19/25], Loss: 3.9215, Accuracy: 14.43%
# End of Epoch [20/25], Loss: 3.9151, Accuracy: 14.47%
# End of Epoch [21/25], Loss: 3.9173, Accuracy: 14.45%
# End of Epoch [22/25], Loss: 3.9146, Accuracy: 14.45%
# End of Epoch [23/25], Loss: 3.9166, Accuracy: 14.39%
# End of Epoch [24/25], Loss: 3.9184, Accuracy: 14.40%
# End of Epoch [25/25], Loss: 3.9187, Accuracy: 14.35%
#
# Final Training accuracy: 14.35%, Final Training loss: 3.9187
# Final Validation accuracy: 19.13%, Final Validation loss: 3.6812

# %%
# Initialize SimpleCNN256 model and hyperparameters
cnn_model_256 = SimpleCNN256()
cnn_model_256.load_state_dict(torch.load("./model_params/cnn_model_256_parameters.pth")) # comment out to train fresh model
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn_model_256.parameters(), lr=0.001)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 25

# Train and then evaulate our model
train_model(cnn_model_256, train_loader, batch_size, criterion, optimizer, device, num_epochs) # optimizer changed to adam
evaluate_model(cnn_model_256, val_loader, criterion, device)

# Assume model is your trained model
torch.save(cnn_model_256.state_dict(), "./model_params/cnn_model_256_parameters.pth")
# Out:
# End of Epoch [1/25], Loss: 3.5241, Accuracy: 20.89%
# End of Epoch [2/25], Loss: 3.5209, Accuracy: 20.75%
# End of Epoch [3/25], Loss: 3.5254, Accuracy: 20.71%
# End of Epoch [4/25], Loss: 3.5132, Accuracy: 21.04%
# End of Epoch [5/25], Loss: 3.5183, Accuracy: 20.75%
# End of Epoch [6/25], Loss: 3.5136, Accuracy: 20.79%
# End of Epoch [7/25], Loss: 3.5067, Accuracy: 21.02%
# End of Epoch [8/25], Loss: 3.5154, Accuracy: 20.98%
# End of Epoch [9/25], Loss: 3.5050, Accuracy: 21.07%
# End of Epoch [10/25], Loss: 3.5086, Accuracy: 21.06%
# End of Epoch [11/25], Loss: 3.5081, Accuracy: 20.99%
# End of Epoch [12/25], Loss: 3.5102, Accuracy: 21.13%
# End of Epoch [13/25], Loss: 3.5064, Accuracy: 20.97%
# End of Epoch [14/25], Loss: 3.5085, Accuracy: 20.98%
# End of Epoch [15/25], Loss: 3.5091, Accuracy: 21.06%
# End of Epoch [16/25], Loss: 3.4984, Accuracy: 21.07%
# End of Epoch [17/25], Loss: 3.5083, Accuracy: 20.98%
# End of Epoch [18/25], Loss: 3.5005, Accuracy: 20.91%
# End of Epoch [19/25], Loss: 3.4952, Accuracy: 21.17%
# End of Epoch [20/25], Loss: 3.4941, Accuracy: 21.17%
# End of Epoch [21/25], Loss: 3.4993, Accuracy: 21.19%
# End of Epoch [22/25], Loss: 3.4904, Accuracy: 21.27%
# End of Epoch [23/25], Loss: 3.4935, Accuracy: 21.38%
# End of Epoch [24/25], Loss: 3.4924, Accuracy: 21.20%
# End of Epoch [25/25], Loss: 3.5005, Accuracy: 21.28%
#
# Final Training accuracy: 21.28%, Final Training loss: 3.5005
# Final Validation accuracy: 23.28%, Final Validation loss: 3.4368

# %% [markdown]
# ##### CNN Observations:
# SimpleCNN's two dense layers are of size 120 and 84 respectively, whereas SimpleCNN256's dense layers are both of size 256.
#
# I tried the model with 512 neurons in each dense layer, but it is overfitting right now. Even with dropout layers, 512 overfits.
#
# The problem persists with 256 neurons too.

# %% [markdown]
# ### Train ResNet18

# %%
# Initialize ResNet18 model and hyperparameters with SGD optimizer
model = ResNet18()
model.load_state_dict(torch.load("./model_params/model_parameters.pth")) # comment out to train fresh model
criterion = nn.CrossEntropyLoss()  # Common choice for of loss for classification problems
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)  # Common choice of optimizer for CNNs
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 20

# Train and then evaulate our model
train_model(model, train_loader, batch_size, criterion, optimizer, device, num_epochs)
evaluate_model(model, val_loader, criterion, device)

# Assume model is your trained model
torch.save(model.state_dict(), "./model_params/model_parameters.pth")
# Out:
# End of Epoch [1/20], Loss: 0.6618, Accuracy: 80.50%
# End of Epoch [2/20], Loss: 0.6202, Accuracy: 81.63%
# End of Epoch [3/20], Loss: 0.5847, Accuracy: 82.52%
# End of Epoch [4/20], Loss: 0.5520, Accuracy: 83.38%
# End of Epoch [5/20], Loss: 0.5127, Accuracy: 84.52%
# End of Epoch [6/20], Loss: 0.4784, Accuracy: 85.56%
# End of Epoch [7/20], Loss: 0.4507, Accuracy: 86.19%
# End of Epoch [8/20], Loss: 0.4214, Accuracy: 87.07%
# End of Epoch [9/20], Loss: 0.4018, Accuracy: 87.62%
# End of Epoch [10/20], Loss: 0.3786, Accuracy: 88.29%
# End of Epoch [11/20], Loss: 0.3582, Accuracy: 88.78%
# End of Epoch [12/20], Loss: 0.3324, Accuracy: 89.62%
# End of Epoch [13/20], Loss: 0.3157, Accuracy: 90.13%
# End of Epoch [14/20], Loss: 0.2946, Accuracy: 90.71%
# End of Epoch [15/20], Loss: 0.2815, Accuracy: 91.16%
# End of Epoch [16/20], Loss: 0.2696, Accuracy: 91.53%
# End of Epoch [17/20], Loss: 0.2586, Accuracy: 91.92%
# End of Epoch [18/20], Loss: 0.2356, Accuracy: 92.60%
# End of Epoch [19/20], Loss: 0.2325, Accuracy: 92.64%
# End of Epoch [20/20], Loss: 0.2278, Accuracy: 92.84%
#
# Final Training accuracy: 92.84%, Final Training loss: 0.2278
# Final Validation accuracy: 57.20%, Final Validation loss: 2.6258

# %% [markdown]
# ### Train ResNet34

# %%
# Initialize ResNet18 model and hyperparameters with SGD optimizer
model_resnet34 = resnet34()
model_resnet34.load_state_dict(torch.load("./model_params/model_resnet34_parameters.pth")) # comment out to train fresh model
criterion = nn.CrossEntropyLoss()  # Common choice for of loss for classification problems
optimizer = optim.SGD(model_resnet34.parameters(), lr=0.01, momentum=0.9)  # Common choice of optimizer for CNNs
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 10

# Train and then evaulate our model
train_model(model_resnet34, train_loader, batch_size, criterion, optimizer, device, num_epochs)
evaluate_model(model_resnet34, val_loader, criterion, device)

# Assume model is your trained model
torch.save(model_resnet34.state_dict(), "./model_params/model_resnet34_parameters.pth")
# Out:
# End of Epoch [1/10], Loss: 0.2867, Accuracy: 91.36%
# End of Epoch [2/10], Loss: 0.2709, Accuracy: 91.77%
# End of Epoch [3/10], Loss: 0.2441, Accuracy: 92.58%
# End of Epoch [4/10], Loss: 0.2297, Accuracy: 93.04%
# End of Epoch [5/10], Loss: 0.2269, Accuracy: 93.11%
# End of Epoch [6/10], Loss: 0.2105, Accuracy: 93.53%
# End of Epoch [7/10], Loss: 0.1886, Accuracy: 94.19%
# End of Epoch [8/10], Loss: 0.1759, Accuracy: 94.68%
# End of Epoch [9/10], Loss: 0.1841, Accuracy: 94.47%
# End of Epoch [10/10], Loss: 0.1596, Accuracy: 95.12%
#
# Final Training accuracy: 95.12%, Final Training loss: 0.1596
# Final Validation accuracy: 57.45%, Final Validation loss: 2.7633

# %% [markdown]
# ### To-Do List:
# - Add dropout layers to our models to work on overfitting issue! DONE
# - Add data augmentation in the training transform to work on overfitting issue! DONE
#     - From the previous two changes, val accuracy is up from 40% to 57%

# %% [markdown]
# - Both Resnet models are now reaching ~57% val accuracy while reaching ~95% training accuracy
#     - Model is overfitting, but still performing better after data augmentation

# %% [markdown]
#  - Remove dropout layers and test models with only data augmentation!
#  - Try changing the learning rate dynamically rather than keeping it constant!
#  - Try changing the kernel size to be 3 or smaller for the simple CNNs; 5 might be too high!
